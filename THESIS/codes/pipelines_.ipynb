# %%
THIS NOTEBOOK RUN IN GOOGLE COLAB

# %%
# !pip install transformers

# %%
import transformers

# %%
# !pip install transformers[sentencepiece]

# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9598048329353333}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598048329353333},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
classifier("I am very stressed about my thesis")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9978539347648621}]

# %%
classifier ("I am very stressed about my thesis, but I think I can do it !")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9973499774932861}]

# %%
classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445989489555359, 0.11197412759065628, 0.04342695698142052]}

# %%
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445989489555359, 0.11197412759065628, 0.04342695698142052]}

# %%
classifier ( "My thesis is about NLP models for it audit",
            candidate_labels=["education","politics","business"],)
# Out:
# {'sequence': 'My thesis is about NLP models for it audit',
#  'labels': ['business', 'education', 'politics'],
#  'scores': [0.4294004738330841, 0.39120781421661377, 0.17939169704914093]}

# %%
classifier ("I think sometimes that i am stupid, but then i remember a have a degree in economics",
            candidate_labels=["funny","sad","love","pessimistic"],)
# Out:
# {'sequence': 'I think sometimes that i am stupid, but then i remember a have a degree in economics',
#  'labels': ['funny', 'pessimistic', 'sad', 'love'],
#  'scores': [0.5379418134689331,
#   0.28281834721565247,
#   0.16447217762470245,
#   0.014767608605325222]}

# %%
classifier ("Sometimes i want to do other things than writing my thesis",
            candidate_labels=["funny","bored","love","tired"],)
# Out:
# {'sequence': 'Sometimes i want to do other things than writing my thesis',
#  'labels': ['tired', 'funny', 'bored', 'love'],
#  'scores': [0.5825480818748474,
#   0.2450948804616928,
#   0.14231249690055847,
#   0.030044542625546455]}

# %%
generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
generator("In this course, we will teach you how to")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to use PHPUnit to create real time tests in SQL Server.\n\n1.1. In SQL Server 2012\n\nThe first step is using an SQL Server 2012 database and database. Next we will'}]

# %%
generator("In this course, we will speak about it audit")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will speak about it audit-first, and we will review how data is collected through use of audits. The course will also provide a practical assessment of how data is stored and used to understand the processes, and problems and problems'}]

# %%
generator ("i like a lot music and books, ")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "i like a lot music and books, \xa0he probably won't have many in his family. A friend with whom he works found some time to go visit the shop and was more than happy to learn that he could just print it out and start"}]

# %%
generator ("i am romantic person and i like read")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'i am romantic person and i like read the story with a bit of humor. The characters are all well drawn, but the story is told in a very slow pace with a few twists and turns inbetween.The characters are very young and i don'}]

# %%
generator ("In this course we will speak about IT audit steps,",num_return_sequences=10,max_length=50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course we will speak about IT audit steps, performance goals and how these have changed in the past years. I will give a small introduction, for those interested in getting into the enterprise and how they did the best they could. This course will'},
#  {'generated_text': 'In this course we will speak about IT audit steps, the latest on the problems. Learn more.'},
#  {'generated_text': 'In this course we will speak about IT audit steps, security, customer audit, and how to use our blockchain technology to effectively deliver a good customer service experience.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'},
#  {'generated_text': 'In this course we will speak about IT audit steps, auditing, and remediation. The purpose of this course is to help us find common issues related to our IT audits, troubleshooting or managing our IT team. It will be useful for us'},
# ...

# %%
generator = pipeline("text-generation", model="distilgpt2")
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to use virtual reality using VR. You will also learn how to use Virtual Virtual Reality using Vive, Oculus'},
#  {'generated_text': 'In this course, we will teach you how to use two basic skills as an educational tool. We will cover some foundational tools and basic skills in the'}]

# %%
generator(
    "In this course we will speak about IT audit",
    max_length=50,
    num_return_sequences=2
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "In this course we will speak about IT audit and business model development, and our methodology. We have also introduced the 'Binary Cloud Platform' which enables us to access the cloud by using the 'Cloud Browser' which is a way to install and"},
#  {'generated_text': 'In this course we will speak about IT audit results for IT industry professionals in the IT sector.\n\n\nThe IT industry in 2015 has experienced a 10% decline. With the year of 2016 in a state of upheaval (2016), there have been'}]

# %%
generator ("My book start like this",max_length=50, num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'My book start like this…\n-L-\nAdvertisements'},
#  {'generated_text': "My book start like this, and just like the book, we've moved on from the fantasy world. It's almost all about the characters in a normal way. It was something I'd always loved and I loved to do - although it's kind"}]

# %%
answering = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
answering ("what an it auditor do ?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-c50f835e7045> in <cell line: 1>()
# ----> 1 answering ("what an it auditor do ?")
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     389         # Convert inputs to features
#     390
# --> 391         examples = self._args_parser(*args, **kwargs)
#     392         if isinstance(examples, (list, tuple)) and len(examples) == 1:
#     393             return super().__call__(examples[0], **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/question_answering.py in __call__(self, *args, **kwargs)
#     217
#     218         for i, item in enumerate(inputs):
# --> 219             inputs[i] = self.normalize(item)
#     220
#     221         return inputs
#
# ...

# %%
# Σωστό
# Δημιουργία ενός παραδείγματος SquadExample
example = {
    'question': 'What does an IT auditor do?',
    'context': 'An IT auditor is responsible for assessing and evaluating an organization\'s technological infrastructure.'
}

# Δημιουργία της λειτουργίας "question-answering" και απάντηση στην ερώτηση
answering = pipeline("question-answering")
result = answering(example)

# Εκτύπωση του αποτελέσματος
print(result)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'score': 0.7230435013771057, 'start': 33, 'end': 104, 'answer': "assessing and evaluating an organization's technological infrastructure"}

# %%
example = {
    'question': 'What does an IT auditor do?',
    'context': 'An IT auditor is responsible for assessing and evaluating an organization\'s technological infrastructure.'
}

answering = pipeline("question-answering",model="bert-large-uncased-whole-word-masking-finetuned-squad")
result = answering(example)

# Εκτύπωση του αποτελέσματος
print(result)
# Out:
# config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %%
unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
unmasker("Today i dont feel like <mask> anything. I just want to lay in my <mask> .", top_k=2)
# Out:
# [[{'score': 0.24400894343852997,
#    'token': 608,
#    'token_str': ' doing',
#    'sequence': '<s>Today i dont feel like doing anything. I just want to lay in my<mask>.</s>'},
#   {'score': 0.06784652173519135,
#    'token': 2410,
#    'token_str': ' writing',
#    'sequence': '<s>Today i dont feel like writing anything. I just want to lay in my<mask>.</s>'}],
#  [{'score': 0.5904539227485657,
#    'token': 3267,
#    'token_str': ' bed',
#    'sequence': '<s>Today i dont feel like<mask> anything. I just want to lay in my bed.</s>'},
#   {'score': 0.1719272881746292,
#    'token': 3581,
#    'token_str': ' sleep',
#    'sequence': '<s>Today i dont feel like<mask> anything. I just want to lay in my sleep.</s>'}]]

# %%
unmasker = pipeline("fill-mask",model="bert-base-cased")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
unmasker("This course will teach you all about [MASK] models.", top_k=2)
# Out:
# [{'score': 0.25963184237480164,
#   'token': 1648,
#   'token_str': 'role',
#   'sequence': 'This course will teach you all about role models.'},
#  {'score': 0.09427252411842346,
#   'token': 1103,
#   'token_str': 'the',
#   'sequence': 'This course will teach you all about the models.'}]

# %%
unmasker("Today i dont feel like [MASK] anything. I just want to lay in my [MASK] .", top_k=2)
# Out:
# [[{'score': 0.6797929406166077,
#    'token': 1833,
#    'token_str': 'doing',
#    'sequence': '[CLS] Today i dont feel like doing anything. I just want to lay in my [MASK]. [SEP]'},
#   {'score': 0.12311696261167526,
#    'token': 2157,
#    'token_str': 'saying',
#    'sequence': '[CLS] Today i dont feel like saying anything. I just want to lay in my [MASK]. [SEP]'}],
#  [{'score': 0.7256531119346619,
#    'token': 1908,
#    'token_str': 'bed',
#    'sequence': '[CLS] Today i dont feel like [MASK] anything. I just want to lay in my bed. [SEP]'},
#   {'score': 0.0434405580163002,
#    'token': 2946,
#    'token_str': 'sleep',
#    'sequence': '[CLS] Today i dont feel like [MASK] anything. I just want to lay in my sleep. [SEP]'}]]

# %%
ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
ner("I am Marianna, i leave in Greece, and I know Korean. I like read books and hear music")
# Out:
# [{'entity_group': 'PER',
#   'score': 0.99711955,
#   'word': 'Marianna',
#   'start': 5,
#   'end': 13},
#  {'entity_group': 'LOC',
#   'score': 0.9998394,
#   'word': 'Greece',
#   'start': 26,
#   'end': 32},
#  {'entity_group': 'MISC',
#   'score': 0.9987213,
#   'word': 'Korean',
#   'start': 45,
#   'end': 51}]

# %%
ner("I like books and music")
# Out:
# []

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# {'score': 0.6949767470359802, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of
    graduates in traditional engineering disciplines such as mechanical, civil,
    electrical, chemical, and aeronautical engineering declined, but in most of
    the premier American universities engineering curricula now concentrate on
    and encourage largely the study of engineering science. As a result, there
    are declining offerings in engineering subjects dealing with infrastructure,
    the environment, and related issues, and greater concentration on high
    technology subjects, largely supporting increasingly complex scientific
    developments. While the latter is important, it should not be at the expense
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other
    industrial countries in Europe and Asia, continue to encourage and advance
    the teaching of engineering. Both China and India, respectively, graduate
    six and eight times as many traditional engineers as does the United States.
    Other industrial countries at minimum maintain their output, while America
    suffers an increasingly serious decline in the number of engineering graduates
    and a lack of well-educated engineers.
"""
)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# [{'summary_text': ' America has changed dramatically during recent years . The number of engineering graduates in the U.S. has declined in traditional engineering disciplines such as mechanical, civil,    electrical, chemical, and aeronautical engineering . Rapidly developing economies such as China and India continue to encourage and advance the teaching of engineering .'}]

# %%
translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-dc2544e71aed> in <cell line: 1>()
# ----> 1 translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
#       2 translator("Ce cours est produit par Hugging Face.")
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     965                 tokenizer_kwargs.pop("torch_dtype", None)
#     966
# --> 967             tokenizer = AutoTokenizer.from_pretrained(
#     968                 tokenizer_identifier, use_fast=use_fast, _from_pipeline=task, **hub_kwargs, **tokenizer_kwargs
#     969             )
#
# ...
